# %% [markdown]
# Building our own function

# %%
x = 5
print("Hello ")

def print_lyrics():
    print("I'm a lumberjaxk, and I'm okay ")
    print("I sleep all night and I Work all day")

print("Yo")
x= x+2 
print(x)
print_lyrics()
# Out:
# Hello
# Yo
# 7
# I'm a lumberjaxk, and I'm okay
# I sleep all night and I Work all day

# %%
def greet(lang):
    if lang == 'es':
        print('Hola')
    elif lang == 'fr':
        print('Bonjour')
    else:
        print("Hello")

greet('en')
greet('es')
greet('fr')
# Out:
# Hello
# Hola
# Bonjour

# %%
# return value

def greet():
    return 'Hello'
print(greet(), "Glenn")
print(greet(), "Sally")
# Out:
# Hello Glenn
# Hello Sally

# %%
# return value
def greet(lang):
    if lang == 'es':
        return'Hola'
    elif lang == 'fr':
        return 'Bonjour'
    else:
        return "Hello"

print(greet('en'), 'Glenn')
print(greet('es'), 'Sally')
print(greet('fr'), 'Michel')
# Out:
# Hello Glenn
# Hola Sally
# Bonjour Michel

# %%
# often a function will make its argumments, do some computation , and return a value to be used as the value of the function call in the calling expression. The return keyword is used for this.
def greet():
    return "Hello"
print(greet(), "VD")
print(greet(), "vilisha")

# %%
big = max('Hello world')
print(big)
# Out:
# w

# %%
# Added two no. using function
def addtwo(a,b):
    added = a + b
    return added 
x = addtwo(3,5)
print(x)
# Out:
# 8

# %% [markdown]
# Rewrite your pay computation with time-and-a
# half for overtime and create a function called
# computepay which takes two parameters ( hours
# and  rate).
# Enter Hours: 45
# Enter Rate: 10

# %%
def computepay(hours, rate):
    if hours > 40:
        overtime = hours -40 
        pay = (40 *rate)+ (overtime *rate * 1.5)
    else:
        pay = hours * rate
    return pay

hours = float(input('Enter Hours: '))
rate = float(input("Enter rate"))

pay = computepay(hours, rate)
print('Pay:' , pay)
# Out:
# Pay: 475.0
